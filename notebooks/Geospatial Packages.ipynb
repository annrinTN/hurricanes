# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import scrapy
from bs4 import BeautifulSoup

# %%
retired_url = 'https://www.thoughtco.com'
ORG_URL = f'{retired_url}/retired-hurricane-names-1435348'

# %%
# pull data from the page
resp = requests.get(ORG_URL)

print(r.content) 
# We want the print statement to be 200
print(resp.status_code)
# Out:
# 200

# %%
# Establish the "soup" object so we can traverse the website content
soup = BeautifulSoup(resp.text, 'html.parser')

# %%
retired_hurricanes=[]

org_repositories = soup.find(id='mntl-sc-block_1-0-13') \
    .find('ul') \
    .findAll('li')

print(f'Total repositories on page: {len(org_repositories)}')
print(org_repositories[0].prettify())
# Out:
# Total repositories on page: 82
# <li>
#  Agnes (1972)
# </li>

# %%
# for loop needed to get data that isn't in a table

# %%
xpath = '/html/body//div/[@id="mntl-sc-block_1-0-13"]'

# %%
from scrapy import Selector 
import requests
url = 'https://www.thoughtco.com/retired-hurricane-names-1435348' 
html = requests.get( url ).content 
sel = Selector( text = html )

# %%
xpath = '/html/body//div/[@id="mntl-sc-block_1-0-13"]/@ul'
sel.extract()
# Out:
# '<html id="structuredContentTemplate_1-0" class="comp taxlevel-3 structuredContentTemplate article-html html mntl-html" data-ab="99,99,99,99,99,99,78,99,99,99" data-resource-version="3.21.0" lang="en" data-adhesive-refresh="billboard3" data-mantle-resource-version="3.11.359" data-reference-resource-version="3.21.0" data-tracking-container="true">\t\t\t\t\n<!--\n<globe-environment environment="prod" application="reference" dataCenter="us-east-1"/>\n-->\n<head class="loc head">\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t<script type="text/javascript"></script>\n\t\t\t\t\t\n\t\t\t\t\t    <link rel="preconnect" href="//js-sec.indexww.com">\n    <link rel="preconnect" href="//ad.crwdcntrl.net">\n    <link rel="preconnect" href="//c.amazon-adsystem.com">\n    <link rel="preconnect" href="//cdn.adsafeprotected.com">\n    <link rel="preconnect" href="//securepubads.g.doubleclick.net">\n\n\t\t\t\t\t\n\t\t\t\t\t    <link rel="dns-prefetch" href="//tags.crwdcntrl.net">\n    <link rel="dns-prefetch" href="/
# ...
